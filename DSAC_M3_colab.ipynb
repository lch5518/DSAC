# %% [markdown]
# 코랩의 서버는 우분투의 운영체제를 사용한다

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.2 LTS

# %% [markdown]
# 서버 cpu정보 확인하기

# %%
# !head /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0

# %% [markdown]
# 메모리 확인하기(약 13GB)

# %%
# !head -n 3 /proc/meminfo
# Out:
# MemTotal:       13335276 kB
# MemFree:        11303512 kB
# MemAvailable:   12669200 kB

# %% [markdown]
# 파이썬 버젼확인하기

# %%
# !python --version
# Out:
# Python 3.6.8
