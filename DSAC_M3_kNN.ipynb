# %% [markdown]
# # kNN

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split

# %%
# 붓꽃 데이터 가져오기
from sklearn.datasets import load_iris
iris = load_iris()
X, y = iris.data, iris.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
clf = SGDClassifier()

# %%
knn.fit(X_train, y_train)
print("kNN score: {:.2f}".format(knn.score(X_test,y_test)))
clf.fit(X_train, y_train)
print("Linear Reg score: {:.2f}".format(clf.score(X_test,y_test)))
# Out:
# kNN score: 0.96
# Linear Reg score: 0.98

# %%
for i in range(1,100,10):
  knn = KNeighborsClassifier(n_neighbors=i)
  knn.fit(X_train,y_train)
  print("K가 ",i, "일 때 정확도 :{:.6f}".format(knn.score(X_test,y_test)))
# Out:
# K가  1 일 때 정확도 :0.955556
# K가  11 일 때 정확도 :0.977778
# K가  21 일 때 정확도 :0.933333
# K가  31 일 때 정확도 :0.911111
# K가  41 일 때 정확도 :0.911111
# K가  51 일 때 정확도 :0.911111
# K가  61 일 때 정확도 :0.800000
# K가  71 일 때 정확도 :0.200000
# K가  81 일 때 정확도 :0.200000
# K가  91 일 때 정확도 :0.200000

# %% [markdown]
# <br><br><br><br>
# # 교차검증(K-fold)

# %%
from sklearn.model_selection import cross_val_score,KFold
cross_val_score(knn,X,y,cv=5).mean().round(4)
# Out:
# 0.66

# %%
# 스케일링
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_sc = sc.fit_transform(X)
cross_val_score(clf,X_sc,y,cv=5).mean().round(4)
# Out:
# 0.96
